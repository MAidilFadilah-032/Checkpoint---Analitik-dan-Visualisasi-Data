# %% [markdown]
# # **GoogleAds DataAnalytics Sales**

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **Memuat Dataset**

# %%
import pandas as pd
file = "/content/drive/MyDrive/DATASET AVD/GoogleAds_DataAnalytics_Sales_Uncleaned.csv"
df =pd.read_csv(file)

df
# Out:
#       Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0     A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1     A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2     A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3     A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4     A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
# ...     ...                    ...     ...          ...      ...    ...
# 2595  A3595    DataAnalyticsCourse    88.0       5344.0  $242.07   17.0
# 2596  A3596    DataAnalyticsCourse   154.0       3211.0  $248.28   14.0
# 2597  A3597    Data Anlytics Corse   113.0       3808.0  $233.25   18.0
# 2598  A3598   Data Analytics Corse   196.0       5853.0  $220.13   16.0
# 2599  A3599   Data Analytics Corse     NaN       5453.0      NaN   12.0
#
#       Conversions  Conversion Rate Sale_Amount     Ad_Date   Location  \
# ...

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# Menampilkan 50 data teratas dari dataset.

# %% [markdown]
# ## **Struktur Data**

# %% [markdown]
# ### **Menampilkan informasi lanjutan**

# %%
df.head(50)
# Out:
#     Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 0   A1000    DataAnalyticsCourse   104.0       4498.0  $231.88   14.0
# 1   A1001    DataAnalyticsCourse   173.0       5107.0  $216.84   10.0
# 2   A1002    Data Anlytics Corse    90.0       4544.0  $203.66   26.0
# 3   A1003  Data Analytcis Course   142.0       3185.0  $237.66   17.0
# 4   A1004   Data Analytics Corse   156.0       3361.0   $195.9   30.0
# 5   A1005    DataAnalyticsCourse   195.0       3776.0  $243.57   10.0
# 6   A1006   Data Analytics Corse   116.0       4480.0  $237.79   17.0
# 7   A1007   Data Analytics Corse   184.0       5060.0  $229.61   23.0
# 8   A1008   Data Analytics Corse   113.0       5434.0      NaN   27.0
# 9   A1009  Data Analytcis Course   166.0       3355.0  $186.78   24.0
# 10  A1010    DataAnalyticsCourse   101.0       5399.0  $236.79   20.0
# 11  A1011   Data Analytics Corse   101.0       3613.0  $208.12   24.0
# ...

# %% [markdown]
# Menampilkan 50 data terbawah dari datasets

# %%
df.tail(50)
# Out:
#       Ad_ID          Campaign_Name  Clicks  Impressions     Cost  Leads  \
# 2550  A3550    Data Anlytics Corse   170.0       5380.0  $204.62   20.0
# 2551  A3551    Data Anlytics Corse   176.0       5036.0  $221.48   13.0
# 2552  A3552   Data Analytics Corse   178.0       4176.0  $198.49   30.0
# 2553  A3553    Data Anlytics Corse    99.0       5663.0  $187.48   22.0
# 2554  A3554    Data Anlytics Corse     NaN       5852.0  $181.96   19.0
# 2555  A3555   Data Analytics Corse   164.0       4725.0  $224.43   18.0
# 2556  A3556    Data Anlytics Corse    94.0       5762.0  $202.12   23.0
# 2557  A3557   Data Analytics Corse    82.0       4773.0  $226.66   10.0
# 2558  A3558  Data Analytcis Course   194.0       4198.0  $217.66   16.0
# 2559  A3559   Data Analytics Corse   176.0       5314.0  $188.23   17.0
# 2560  A3560    Data Anlytics Corse   170.0       3401.0   $235.7   10.0
# 2561  A3561    Data Anlytics Corse   144.0       3509.0  $193.65   28.0
# ...

# %% [markdown]
# Pada dataset ini terdapat 13 kolom dan 2600 baris.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2600 entries, 0 to 2599
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ad_ID            2600 non-null   object
#  1   Campaign_Name    2600 non-null   object
#  2   Clicks           2488 non-null   float64
#  3   Impressions      2546 non-null   float64
#  4   Cost             2503 non-null   object
#  5   Leads            2552 non-null   float64
#  6   Conversions      2526 non-null   float64
#  7   Conversion Rate  1974 non-null   float64
#  8   Sale_Amount      2461 non-null   object
#  9   Ad_Date          2600 non-null   object
#  10  Location         2600 non-null   object
#  11  Device           2600 non-null   object
#  12  Keyword          2600 non-null   object
# dtypes: float64(5), object(8)
# memory usage: 264.2+ KB

# %% [markdown]
# ### **Mengembalikan jumlah baris dan kolom dalam dataset**

# %% [markdown]
# Dataset ini memiliki 13 kolom dan 2600 baris.

# %%
df.shape
# Out:
# (2600, 13)

# %% [markdown]
# ### **Menampilkan tipe data dari setiap kolom**

# %% [markdown]
# Pada dataset ini terdapat 8 kolom yang menggunakan tipe data object dan 5 kolom yang menggunakan tipe data float.
#
# Kolom yang menggunakan tipe data object adalah:
# - Ad_ID
# - Campaign_Name
# - Cost
# - Sale_Amount
# - Ad_Date
# - Location
# - Device
# - Keyword
# <br>
#
# Kolom yang menggunakan tipe data float adalah:
# - Clicks
# - Impressions
# - Leads
# - Conversions
# - Conversions Rate

# %%
df.dtypes
# Out:
# Ad_ID               object
# Campaign_Name       object
# Clicks             float64
# Impressions        float64
# Cost                object
# Leads              float64
# Conversions        float64
# Conversion Rate    float64
# Sale_Amount         object
# Ad_Date             object
# Location            object
# Device              object
# Keyword             object
# dtype: object

# %% [markdown]
# ## **Statistik Deskriptif**

# %% [markdown]
# ### **Menampilkan statistik ringkasan**

# %% [markdown]
# Memperlihatkan statistik ringkasan pada dataset seperti mean, median, minimum, maksimum, dan kuartil.

# %%
df.describe()
# Out:
#             Clicks  Impressions        Leads  Conversions  Conversion Rate
# count  2488.000000  2546.000000  2552.000000  2526.000000      1974.000000
# mean    138.956994  4523.280833    20.003918     6.519002         0.048979
# std      34.619376   869.927913     6.032317     2.272573         0.019987
# min      80.000000  3000.000000    10.000000     3.000000         0.015000
# 25%     110.000000  3764.000000    15.000000     5.000000         0.035000
# 50%     139.000000  4518.500000    20.000000     7.000000         0.046000
# 75%     169.000000  5279.500000    25.000000     9.000000         0.058000
# max     199.000000  5999.000000    30.000000    10.000000         0.123000

# %% [markdown]
# ### **Menghitung jumlah kemunculan nilai unik dalam suatu kolom**

# %% [markdown]
# Nilai untik yang muncul pada dataset ini berjumlah 1709 baris dan 1 kolom.

# %%
df.value_counts()
# Out:
# Ad_ID  Campaign_Name          Clicks  Impressions  Cost     Leads  Conversions  Conversion Rate  Sale_Amount  Ad_Date     Location   Device   Keyword
# A3598  Data Analytics Corse   196.0   5853.0       $220.13  16.0   7.0          0.036            $1558        2024-11-08  hydrebad   Tablet   data anaytics training    1
# A1000  DataAnalyticsCourse    104.0   4498.0       $231.88  14.0   7.0          0.058            $1892        2024-11-16  hyderabad  desktop  learn data analytics      1
# A1001  DataAnalyticsCourse    173.0   5107.0       $216.84  10.0   8.0          0.046            $1679        20-11-2024  hyderabad  mobile   data analytics course     1
# A1006  Data Analytics Corse   116.0   4480.0       $237.79  17.0   5.0          0.043            $1640        06-11-2024  hyderabad  TABLET   data analytics course     1
# ...

# %% [markdown]
# ### **Menghitung rata-rata, median, dan standar deviasi**

# %% [markdown]
# Memperlihatkan jumlah rata-rata, median, dan standar deviasi pada dataset.

# %%
df.mean(numeric_only=True), df.median(numeric_only=True), df.std(numeric_only=True)
# Out:
# (Clicks              138.956994
#  Impressions        4523.280833
#  Leads                20.003918
#  Conversions           6.519002
#  Conversion Rate       0.048979
#  dtype: float64,
#  Clicks              139.000
#  Impressions        4518.500
#  Leads                20.000
#  Conversions           7.000
#  Conversion Rate       0.046
#  dtype: float64,
#  Clicks              34.619376
#  Impressions        869.927913
#  Leads                6.032317
#  Conversions          2.272573
#  Conversion Rate      0.019987
#  dtype: float64)

# %% [markdown]
# ### **Menghitung korelasi antar kolom numerik**

# %% [markdown]
# Memperlihatkan kolerasi antar kolom numeric, jika semalin mendekati angka 1 maka ia berkorelasi positif, jika ia mendekati 0 atau bernilai 0 maka tidak ada korelasinya satu sama lain, dan jika ia mendekati -1 atau bernilai -1 maka ia berkorelasi negatif dengan kolom numerik tersebut.

# %%
df.corr(numeric_only=True)
# Out:
#                    Clicks  Impressions     Leads  Conversions  Conversion Rate
# Clicks           1.000000     0.001500  0.054291     0.006728        -0.490762
# Impressions      0.001500     1.000000 -0.035502    -0.013960         0.015196
# Leads            0.054291    -0.035502  1.000000     0.023439        -0.014123
# Conversions      0.006728    -0.013960  0.023439     1.000000         0.641099
# Conversion Rate -0.490762     0.015196 -0.014123     0.641099         1.000000

# %% [markdown]
# ## **Memerikasa Incosistent Values**

# %% [markdown]
# Inkosisten values pada kolom Campaign_Name terdapat pada bagian jarak dan juga penggunaan kata course dan corse. contohnya 'DataAnalyticsCourse', 'Data Anlytics Corse', 'Data Analytcis Course', dan 'Data Analytics Corse'.

# %%
print(df['Campaign_Name'].unique())
# Out:
# ['DataAnalyticsCourse' 'Data Anlytics Corse' 'Data Analytcis Course'
#  'Data Analytics Corse']

# %% [markdown]
# Inkosisten values pada kolom Location terapat pada bagian huruf kapital, meski lokasinya sama jika pemberian huruf kapitalnya berbeda maka akan di anggap berbeda, seperti 'hyderabad', 'HYDERABAD', 'Hyderbad', dan 'hydrebad'.

# %%
print(df['Location'].unique())
# Out:
# ['hyderabad' 'HYDERABAD' 'Hyderbad' 'hydrebad']

# %% [markdown]
# Inkosisten values pada kolom Device terdapat inkonsisten dalam pemberian huruf kapital seperti 'desktop', 'mobile', 'Desktop', 'tablet', 'MOBILE', 'TABLET' 'Tablet', 'Mobile', dan 'DESKTOP'.

# %%
print(df['Device'].unique())
# Out:
# ['desktop' 'mobile' 'Desktop' 'tablet' 'MOBILE' 'TABLET' 'Tablet' 'Mobile'
#  'DESKTOP']

# %% [markdown]
# Inkosisten values pada kolom Keyword. terdapat beberapa kata yang berbeda namun tetap memiliki arti yang sama satu sama lain seperti 'learn data analytics', 'data analytics course', 'data analitics online', 'data anaytics training' 'online data analytic', dan 'analytics for data'

# %%
print(df['Keyword'].unique())
# Out:
# ['learn data analytics' 'data analytics course' 'data analitics online'
#  'data anaytics training' 'online data analytic' 'analytics for data']

# %% [markdown]
# Inkosisten values pada kolom Ad_Date, format yang digunakan cukup tidak konsisten seperti memakai forma yyyy/mm/dd dan dd/mm/yyyy.

# %%
print(df['Ad_Date'].unique())
# Out:
# ['2024-11-16' '20-11-2024' '2024/11/16' '2024-11-26' '2024-11-22'
#  '16-11-2024' '06-11-2024' '2024/11/24' '2024/11/12' '14-11-2024'
#  '2024/11/22' '2024/11/27' '12-11-2024' '2024-11-04' '2024-11-29'
#  '2024-11-10' '2024/11/07' '2024-11-05' '2024/11/21' '2024/11/08'
#  '2024-11-20' '30-11-2024' '2024-11-02' '2024-11-21' '2024-11-23'
#  '2024/11/13' '2024-11-08' '22-11-2024' '2024/11/03' '2024-11-25'
#  '01-11-2024' '2024-11-07' '09-11-2024' '2024-11-14' '2024/11/09'
#  '29-11-2024' '15-11-2024' '11-11-2024' '2024-11-24' '21-11-2024'
#  '2024/11/26' '26-11-2024' '18-11-2024' '2024-11-11' '23-11-2024'
#  '2024/11/20' '27-11-2024' '04-11-2024' '2024/11/06' '2024-11-09'
#  '2024/11/25' '17-11-2024' '2024/11/28' '2024-11-03' '2024-11-19'
#  '2024/11/23' '03-11-2024' '2024/11/15' '2024-11-01' '2024-11-28'
#  '2024-11-15' '2024/11/17' '2024-11-30' '24-11-2024' '05-11-2024'
#  '2024-11-18' '2024/11/04' '2024/11/05' '2024/11/01' '2024/11/11'
# ...

# %% [markdown]
# ## **Memeriksa Missing Values**

# %% [markdown]
# Beberapa misssing value yang terdapat di beberapa kolom yaitu:
# - Kolom Clicks terdapat 4.3 persen missing values
# - Kolom Impressions terdapat 2 persen missing values
# - Kolom Cost terdapat 3.7 persen missing values
# - Kolom Leads terdapat 1.8 persen missing values
# - Kolom Conversions terdapat 2.8 persen missing values
# - Kolom Conversions Rate terdapat 24.7 persen missing values
# - Kolom Sale_Amount terdapat 5.3 persen missing values

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                  Null Ratio in %
# Ad_ID                   0.000000
# Campaign_Name           0.000000
# Clicks                  4.307692
# Impressions             2.076923
# Cost                    3.730769
# Leads                   1.846154
# Conversions             2.846154
# Conversion Rate        24.076923
# Sale_Amount             5.346154
# Ad_Date                 0.000000
# Location                0.000000
# Device                  0.000000
# Keyword                 0.000000

# %% [markdown]
# ## **Memeriksa Duplicated Values**

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ad_ID, Campaign_Name, Clicks, Impressions, Cost, Leads, Conversions, Conversion Rate, Sale_Amount, Ad_Date, Location, Device, Keyword]
# Index: []

# %% [markdown]
# ## **Memeriksa Outliers**

# %% [markdown]
# Melihat nilai ekstrem (outliers) pada kolom yang bertipe data kan numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis dan model yang akan kita bangun nantinya.
# <br>
#
# Terdapat Outliers pada kolom Conversion Rate sejumlah 3.4 persen dan kolom lainnya bersih dari outliers.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom            Persentase Outliers
# Clicks                      0.000000
# Impressions                 0.000000
# Leads                       0.000000
# Conversions                 0.000000
# Conversion Rate             3.423077

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparision (Perbandingan)**

# %% [markdown]
# Perbandingan setiap clicks yang di dapatkan dari Device (Perangkat). karena inkonsistensi penulisan pada kolom perangkat membuat beberapa data menjadi terpisah meski data tersebut sama seperti desktop dan Desktop, ini adalah dua perangkat yang sama namun terlihat berbeda dalam grafik karen perbedaan penulisan dan dianggap sebagai variabel yang berbeda.

# %%
variabel = df.groupby('Device')['Clicks'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=variabel.index, y=variabel.values, palette='viridis', hue=variabel.index, legend=False)
plt.title('Total Clicks by Device')
plt.xlabel('Device')
plt.ylabel('Total Clicks')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## **Composition (Komposisi)**

# %% [markdown]
# Komposisi dari setiap penjualan yang dihasilkan oleh perangkat, karena penulisan pada perangkat tidak konsisten membuatnya menjadi terpisah beberapa bagian meski termasuk data yang sama.

# %%
df['Sale_Amount'] = df['Sale_Amount'].replace('[$,]', '', regex=True).astype(float)

df['Device'] = df['Device'].str.lower()

variabel = df.groupby('Device')['Sale_Amount'].sum().sort_values(ascending=False)
variabel2 = variabel.head(9)

plt.figure(figsize=(8, 8))
ax = variabel2.plot(kind='pie',
                    autopct='%1.1f%%',
                    startangle=140,
                    colors=['#ff9999','#66b3ff','#99ff99'],
                    ylabel='')

plt.title('Device Composition by Sale Amount (Cleaned)')
plt.axis('equal')
plt.savefig('device_pie_chart.png')
plt.show()

# %% [markdown]
# ## **Distribution (Distribusi)**

# %% [markdown]
# Distribusi yang terdapat dibawah ini adalah jenis uniform (seragam) Rentang Data tersebar antara nilai 1000 hingga 2000 pada sumbu Sale_Amount.
#
# Frekuensi setiap bin atau kelompok nilai memiliki jumlah klik yang relatif sama, yaitu berkisar di angka 110 hingga 140.

# %% [markdown]
# ### **Distribusi Pada Sale Amount**

# %% [markdown]
# Pada Distribusi Sale Amount, terlihat semua barnya seragam dan stabil.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Sale_Amount'], bins=20, kde=True)
plt.title('Distribution of Sale Amount')
plt.xlabel('Sale_Amount')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ### **Distribusi Pada Leads**

# %% [markdown]
# Pada Distribusi Leads, barnya terlihat seragam namun di bar terakhir ada peningkatan nilai yang lumayan tinggi.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Leads'], bins=20, kde=True)
plt.title('Distribution of Leads')
plt.xlabel('Sale_Amount')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ### **Distribusi Pada Impressions**

# %% [markdown]
# Pada distribusi Impression terlihat semua barnya stabil dan seragam satu sama lain.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Impressions'], bins=20, kde=True)
plt.title('Distribution of Impressions')
plt.xlabel('Sale_Amount')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ### **Distribusi Pada Clicks**

# %% [markdown]
# Pada distribusi Clicks hampir semua terlihat seragam, namun ada peningkatan nilai di tengah distribusi.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Clicks'], bins=20, kde=True)
plt.title('Distribution of Clicks')
plt.xlabel('Sale_Amount')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ### **Distribusi Pada Conversions**

# %% [markdown]
# Pada distribusi Conversions, tabelnya terlihat stabil serta seragam dan tidak ada nilai yang terlalu tinggi dan terlalu rendah.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Conversions'], bins=20, kde=True)
plt.title('Distribution of Conversions')
plt.xlabel('Sale_Amount')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ### **Distribusi Pada Coversion Rate**

# %% [markdown]
# Pada distribusi Conversion Rate terlihat barnya sangat tinggi dibagian kiri lalu turun dan naik seperti motif distribusi lonceng atau bell.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Conversion Rate'], bins=20, kde=True)
plt.title('Distribution of Conversion Rate')
plt.xlabel('Sale_Amount')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ### **Distribusi Pada Cost**

# %% [markdown]
# Pada distribusi Cost disini saya mengubah tipe data cost terlebih dahulu agar bisa dilihat nilai distribusinya agar dapat menentukan memakai cara apa untuk mencari missing valuesnya.
#
# terlihat pada distribusi ini, barnya terlihat seragam dan stabil.

# %%
df['Cost'] = df['Cost'].astype(str).str.replace(r'[$,Rp ]', '', regex=True).str.replace(',', '')

df['Cost'] = pd.to_numeric(df['Cost'], errors='coerce')

df_clean = df.dropna(subset=['Cost'])

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df_clean['Cost'], bins=30, kde=True, color='blue', edgecolor='black')

plt.title('Distribusi Biaya (Cost)')
plt.xlabel('Nilai Cost')
plt.ylabel('Frekuensi')
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# ## **Relationship (Hubungan)**

# %% [markdown]
# - dari grafik ini tidak ada hubungan dominan antara nominal penjualan tertentu dengan jumlah klik.
#
# - jumlah klik yang didapatkan pada transaksi bernilai rendah  hampir sama banyaknya dengan jumlah klik pada transaksi bernilai tinggi.
#
# - Tidak ada harga tertentu yang memicu lonjakan klik secara drastis.
#
# - Pada bagian  conversion rate dengan clicks mereka berkorelasi negatif, yang artinya clicks bisa mengurangi jumlah conversions rate atau sebaliknya.

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    data=df[['Clicks','Impressions','Cost','Leads','Conversions','Conversion Rate','Sale_Amount']].corr(),
    annot=True,
    cmap='viridis',
    fmt='.2f'
)

plt.title('Korelasi Antar Variabel Numerik pada Dataset Iklan Google')
plt.show()

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Tipe Data**

# %% [markdown]
# Clicks, Impressions, Leads, dan Conversions diubah menjadi INT64 karena kolom tersebut tidak memerlukan desimal contohnya seperti clicks yang jumlahnya bilangan bulat dan bukan desimal.
#
# Cost, Sale_Amount menjadi Float64 Karena kedua kolom ini memerlukan perhitungan yang jelas, jika memakai simbol $ atau , maka akan mengganggu perhitungan yang akan di lakukan selanjutnya.

# %%
df['Clicks'] = pd.to_numeric(df['Clicks'], errors='coerce')

# %%
df['Clicks'] = df['Clicks'].astype('Int64')

# %%
df['Impressions'] = pd.to_numeric(df['Impressions'], errors='coerce')

# %%
df['Impressions'] = df['Impressions'].astype('Int64')

# %%
df['Leads'] = pd.to_numeric(df['Leads'], errors='coerce')

# %%
df['Leads'] = df['Leads'].astype('Int64')

# %%
df['Conversions'] = pd.to_numeric(df['Conversions'], errors='coerce')

# %%
df['Conversions'] = df['Conversions'].astype('Int64')

# %%
df['Cost'] = pd.to_numeric(df['Cost'], errors='coerce')

# %%
df['Cost'] = df['Cost'].astype('Float64')

# %%
df['Cost'] = df['Cost'].replace('[$,]', '', regex=True).astype(float)
df['Sale_Amount'] = df['Sale_Amount'].replace('[$,]', '', regex=True).astype(float)

# %%
df['Sale_Amount'] = pd.to_numeric(df['Sale_Amount'], errors='coerce')

# %%
df['Sale_Amount'] = df['Sale_Amount'].astype('Float64')

# %%
df['Sale_Amount'] = df['Sale_Amount'].replace('[/$,]', '', regex=True).astype(float)

# %%
df . head(100)
# Out:
#     Ad_ID          Campaign_Name  Clicks  Impressions    Cost  Leads  \
# 0   A1000    DataAnalyticsCourse     104         4498  231.88     14
# 1   A1001    DataAnalyticsCourse     173         5107  216.84     10
# 2   A1002    Data Anlytics Corse      90         4544  203.66     26
# 3   A1003  Data Analytcis Course     142         3185  237.66     17
# 4   A1004   Data Analytics Corse     156         3361  195.90     30
# ..    ...                    ...     ...          ...     ...    ...
# 95  A1095    Data Anlytics Corse     183         3947  197.30     15
# 96  A1096    DataAnalyticsCourse     113         3690  229.42     20
# 97  A1097  Data Analytcis Course     101         5943  187.32     27
# 98  A1098    DataAnalyticsCourse     189         5357  222.50     24
# 99  A1099    Data Anlytics Corse     154         3596  236.14     30
#
#     Conversions  Conversion Rate  Sale_Amount     Ad_Date   Location   Device  \
# ...

# %% [markdown]
# ## **Inconsisten Values**

# %% [markdown]
# - Disini saya mengubah format penanggalannya menjadi yyyy/mm/dd agar lebih konsisten dan mudah untuk dinavigasi
#
# - Pada Campaign_Name saya mengubah semuanya menjadi Data Analytics Course karena ketidak konsistenan sebelumnya memiliki arti yang sama.
#
# - Pada Location saya mengubah semuanya menjadi HYDERBAD agar lebih konsisten dan tidak terpisah.
#
# - Pada bagian Device saya mengubah semuanya menjadi huruf kapital agar tidak terpisah dan terurai, seperti MOBILE, DESKTOP, dan, TABLET.

# %%
import pandas as pd
df["Ad_Date"] = pd.to_datetime(df["Ad_Date"], format="mixed")
df["Ad_Date"].head(5)
# Out:
# 0   2024-11-16
# 1   2024-11-20
# 2   2024-11-16
# 3   2024-11-26
# 4   2024-11-22
# Name: Ad_Date, dtype: datetime64[ns]

# %%
print(df['Campaign_Name'].unique())
# Out:
# ['DataAnalyticsCourse' 'Data Anlytics Corse' 'Data Analytcis Course'
#  'Data Analytics Corse']

# %%
df['Campaign_Name'] = df['Campaign_Name'].str.upper()

# %%
df['Campaign_Name'] = df['Campaign_Name'].replace({
    'DATAANALYTICSCOURSE': 'DATA ANALYTICS COURSE',
    'DATA ANLYTICS CORSE': 'DATA ANALYTICS COURSE',
    'DATA ANALYTCIS COURSE': 'DATA ANALYTICS COURSE',
    'DATA ANALYTICS CORSE': 'DATA ANALYTICS COURSE'
})

for col in ['Campaign_Name']:
    print(df[col].unique())
# Out:
# ['DATA ANALYTICS COURSE']

# %%
print(df['Location'].unique())
# Out:
# ['hyderabad' 'HYDERABAD' 'Hyderbad' 'hydrebad']

# %%
df['Location'] = df['Location'].str.upper()

# %%
df['Location'] = df['Location'].replace({
    'hyderabad': 'HYDERABAD',
    'Hyderbad': 'HYDERABAD',
    'hydrebad': 'HYDERABAD',
    'HYDERBAD': 'HYDERABAD',
    'HYDREBAD': 'HYDERABAD'
})

for col in ['Location']:
    print(df[col].unique())
# Out:
# ['HYDERABAD']

# %%
print(df['Device'].unique())
# Out:
# ['desktop' 'mobile' 'tablet']

# %%
df['Device'] = df['Device'].str.upper()

# %%
df['Device'] = df['Device'].replace({
    'mobile': 'MOBILE',
    'Mobile': 'MOBILE',
    'desktop': 'DESKTOP',
    'Desktop': 'DESKTOP',
    'tablet': 'TABLET',
    'Tablet': 'TABLET'
})

for col in ['Device']:
    print(df[col].unique())
# Out:
# ['DESKTOP' 'MOBILE' 'TABLET']

# %% [markdown]
# ## **Missing Values**

# %% [markdown]
# Pada Dataset ini saya menggunakan Mean atau rata-rata untuk mencari missing values, alasan saya menggunakan mean karena pada distribusi semuanya terlihat seragam dan stabil.

# %%
df['Clicks'] = df['Clicks'].fillna(round(df['Clicks'].dropna().mean()))

# %%
df['Impressions'] = df['Impressions'].fillna(round(df['Impressions'].dropna().mean()))

# %%
df['Cost'] = df['Cost'].fillna(0)

# %%
df['Cost'] = df['Cost'].astype(int)

# %%
df['Cost'] = df['Cost'].fillna(round(df['Cost'].dropna().mean()))

# %%
df['Leads'] = df['Leads'].fillna(round(df['Leads'].dropna().mean()))

# %%
df['Conversions'] = df['Conversions'].fillna(round(df['Conversions'].dropna().mean()))

# %%
df['Conversion Rate'] = df['Conversion Rate'].fillna(round(df['Conversion Rate'].dropna().median()))

# %%
df['Sale_Amount'] = df['Sale_Amount'].fillna(round(df['Sale_Amount'].dropna().mean()))

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                  Null Ratio in %
# Ad_ID                        0.0
# Campaign_Name                0.0
# Clicks                       0.0
# Impressions                  0.0
# Cost                         0.0
# Leads                        0.0
# Conversions                  0.0
# Conversion Rate              0.0
# Sale_Amount                  0.0
# Ad_Date                      0.0
# Location                     0.0
# Device                       0.0
# Keyword                      0.0

# %% [markdown]
# ## **Duplicated Values**

# %% [markdown]
# Pada Dataset ini tidak ada Duplicated Values yang perlu di atasi.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ad_ID, Campaign_Name, Clicks, Impressions, Cost, Leads, Conversions, Conversion Rate, Sale_Amount, Ad_Date, Location, Device, Keyword]
# Index: []

# %% [markdown]
# ## **Outliers**

# %% [markdown]
# - Pada Outliers terdapat pada kolom Cost dan Conversion Rate, saya memperbaiki outliers pada cost agar semua data tidak ada yang bias dan mengganggu hasil akhir keuangan pada Dataser.
#
# - Lalu pada Conversion_Rate atau metrik yang mengukur efektivitas iklan, berfungsi untuk membedakan mana pengunjung yang "hanya lihat-lihat" dengan pengunjung yang "niat beli". dilakukan pembersihan outliers untuk dapat membedakan setiap pengunjung yang masuk kedalam iklan tersebut.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom            Persentase Outliers
# Clicks                      0.000000
# Impressions                 0.000000
# Cost                        3.730769
# Leads                       0.000000
# Conversions                 0.000000
# Conversion Rate             0.923077
# Sale_Amount                 0.000000

# %%
columns_to_impute = ["Conversion Rate", "Conversion Rate"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
columns_to_impute = ["Cost", "Cost"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)
# Out:
# /tmp/ipykernel_14057/2329580908.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[231.  216.  203.  ... 233.  220.  139.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom            Persentase Outliers
# Clicks                           0.0
# Impressions                      0.0
# Cost                             0.0
# Leads                            0.0
# Conversions                      0.0
# Conversion Rate                  0.0
# Sale_Amount                      0.0

# %% [markdown]
# # **Contruct Data**

# %% [markdown]
# Disini saya menambahkan kolom Profit untuk mengetahui berapa banyak keuntungan yang di dapatkan dari tiap pemasaran iklan.

# %%
df['Profit'] = df['Sale_Amount'] - df['Cost']

# %%
df. head(50)
# Out:
#     Ad_ID          Campaign_Name  Clicks  Impressions   Cost  Leads  \
# 0   A1000  DATA ANALYTICS COURSE     104         4498  231.0     14
# 1   A1001  DATA ANALYTICS COURSE     173         5107  216.0     10
# 2   A1002  DATA ANALYTICS COURSE      90         4544  203.0     26
# 3   A1003  DATA ANALYTICS COURSE     142         3185  237.0     17
# 4   A1004  DATA ANALYTICS COURSE     156         3361  195.0     30
# 5   A1005  DATA ANALYTICS COURSE     195         3776  243.0     10
# 6   A1006  DATA ANALYTICS COURSE     116         4480  237.0     17
# 7   A1007  DATA ANALYTICS COURSE     184         5060  229.0     23
# 8   A1008  DATA ANALYTICS COURSE     113         5434  139.5     27
# 9   A1009  DATA ANALYTICS COURSE     166         3355  186.0     24
# 10  A1010  DATA ANALYTICS COURSE     101         5399  236.0     20
# 11  A1011  DATA ANALYTICS COURSE     101         3613  208.0     24
# 12  A1012  DATA ANALYTICS COURSE     125         3259  191.0     18
# ...

# %% [markdown]
# # **Data Reduction**

# %% [markdown]
# Saya tidak mengurangi kolom ataupun baris pada Dataset ini karena setiap kolom memiliki fungsi dan peran yang penting untuk kesatuan dataset, jika salah satu di hapus seperti contohnya Impression yang berfungsi untuk menghitung berapa kali iklan Anda muncul atau ditampilkan di layar perangkat pengguna, jika dihapus maka akan sulit untuk mendeteksi pengguna yang mendapatkan iklan tersebut.

# %% [markdown]
# # **Hasil Akhir Dataset**

# %%
df. head(2600)
# Out:
#       Ad_ID          Campaign_Name  Clicks  Impressions   Cost  Leads  \
# 0     A1000  DATA ANALYTICS COURSE     104         4498  231.0     14
# 1     A1001  DATA ANALYTICS COURSE     173         5107  216.0     10
# 2     A1002  DATA ANALYTICS COURSE      90         4544  203.0     26
# 3     A1003  DATA ANALYTICS COURSE     142         3185  237.0     17
# 4     A1004  DATA ANALYTICS COURSE     156         3361  195.0     30
# ...     ...                    ...     ...          ...    ...    ...
# 2595  A3595  DATA ANALYTICS COURSE      88         5344  242.0     17
# 2596  A3596  DATA ANALYTICS COURSE     154         3211  248.0     14
# 2597  A3597  DATA ANALYTICS COURSE     113         3808  233.0     18
# 2598  A3598  DATA ANALYTICS COURSE     196         5853  220.0     16
# 2599  A3599  DATA ANALYTICS COURSE     139         5453  139.5     12
#
#       Conversions  Conversion Rate  Sale_Amount    Ad_Date   Location  \
# ...

# %% [markdown]
# # **Chart**

# %% [markdown]
# ## **Bar Chart**

# %%
berat_porsi = df.groupby('Device')['Clicks'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(berat_porsi.index, berat_porsi.values, color='navy')

plt.xlabel('Device')
plt.ylabel('Clicks')
plt.title('Perbandingan Rata-rata Clicks Setiap Device')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Pie Chart**

# %%
plt.figure(figsize=(10, 6))
plt.pie(df['Device'].value_counts(), labels=df['Device'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold']) # colors (warna)
plt.title('Jumlah Pendistribusian Pada Kolom Device')
plt.show()

# %% [markdown]
# ## **Line Chart**

# %% [markdown]
# ### **Line Chart Berdasarkan Tahun**

# %%
df['Ad_Date'] = pd.to_datetime(df['Ad_Date'])

VARIABEL1 = df.groupby(df['Ad_Date'].dt.year).size()

plt.figure(figsize=(20, 6))
plt.plot(VARIABEL1.index, VARIABEL1.values, marker='o', color='red')
plt.title('Tren Distribusi Dari Tiap Tahunnya', fontsize=16)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.grid(True)
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Line Chart Berdasarkan Bulan**

# %%
df['Ad_Date'] = pd.to_datetime(df['Ad_Date'])

GrupPerBulan = df.groupby(df['Ad_Date'].dt.to_period('M')).size()

plt.figure(figsize=(20, 6))
plt.plot(GrupPerBulan.index.astype(str), GrupPerBulan.values, marker='o', color='blue')
plt.title('Tren Distribusi Dari Tiap Bulannya', fontsize=16)
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.grid(True)
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Line Chart Berdasarkan Tanggal**

# %%
VARIABEL1 = df.groupby(df['Ad_Date'].dt.to_period('D')).size()

plt.figure(figsize=(30, 8))
plt.plot(VARIABEL1.index.astype(str), VARIABEL1.values, marker='o', color='blue')

plt.title('Tren Distribusi Dari Tiap Tanggalnya', fontsize=16)
plt.xlabel('Tanggal', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)

plt.grid(True)
plt.gcf().autofmt_xdate()
plt.tight_layout()

plt.show()

# %% [markdown]
# ## **Histogram**

# %% [markdown]
# ###**Histogram Pada Kolom Clicks**

# %% [markdown]
# Pada kolom clicks histogram yang terlihat seragam dan stabil, namun ada peningkatan tinggi di tengah.

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Clicks'], bins=20, color='blue', edgecolor='black')
plt.title('Histogram Pada Kolom Clicks')
plt.xlabel('Clicks')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ###**Histogram Pada Kolom Impressions**

# %% [markdown]
# Pada histogram di kolom impressions semua bar terlihat stabil dan beragam, tidak ada lonjakan atau penurunan nilai yang signifikan.

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Impressions'], bins=20, color='blue', edgecolor='black')
plt.title('Histogram Pada Kolom Impressions')
plt.xlabel('Impressions')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ###**Histogram Pada Kolom Cost**

# %% [markdown]
# Pada histogram cost terlihat sedikit unik, ada outliers dengan jumlah 140 yang berbeda dengan bar lainnya yang berjumlah 180 sampai 240.

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Cost'], bins=20, color='blue', edgecolor='black')
plt.title('Histogram Pada Kolom Cost')
plt.xlabel('Cost')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ###**Histogram Pada Kolom Leads**

# %% [markdown]
# Pada histogram Leads terlihat seragam dan stabil, namun ada dua bar yang memiliki peningkatan nilai yang berbeda dengan bar lainnya.

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Leads'], bins=20, color='blue', edgecolor='black')
plt.title('Histogram Pada Kolom Leads')
plt.xlabel('Leads')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ###**Histogram Pada Kolom Conversions**

# %% [markdown]
# Pada histogram Conversions terlihat semua bar memiliki keseragaman pada nilai distribusi, dan tidak ada lonjakan yang signifikan pada histogram ini.

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Conversions'], bins=20, color='blue', edgecolor='black')
plt.title('Histogram Pada Kolom Conversions')
plt.xlabel('Conversions')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ###**Histogram Pada Kolom Conversions Rate**

# %% [markdown]
# pada histogram conversion rate terlihat ada nilai sangat tinggi pada sisi kiri namun mulai menurun secara drastis lalu kembali naik, sehingga membuat terlihat seperti bentuk lonceng atau bell.

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Conversion Rate'], bins=20, color='blue', edgecolor='black')
plt.title('Histogram Pada Kolom Conversions Rate')
plt.xlabel('Conversions Rate')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ###**Histogram Pada Kolom Sale Amount**

# %% [markdown]
# Pada histogram sale amount atau penjualan, kita dapat melihat bahwa barnya terlihat seragam namun di tengah nilai terdapat lonjakan tinggi dan mulai kembali stabil setelahnya.

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Sale_Amount'], bins=20, color='blue', edgecolor='black')
plt.title('Histogram Pada Kolom Sale Amount')
plt.xlabel('Sale Amount')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ###**Histogram Pada Kolom Profit**

# %% [markdown]
# Pada histogram profit dapat terlihat bahwa ini ada tampilan untuk distribusi lonceng atau bell, karena di awali dari nilai rendah lalu naik sehingga membuat bentuk seperti puncak gunung, lalu turun kembali ke bawah.

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Profit'], bins=20, color='blue', edgecolor='black')
plt.title('Histogram Pada Kolom Profit')
plt.xlabel('Profit')
plt.ylabel('Distribusi')
plt.show()

# %% [markdown]
# ## **Box Plot**

# %% [markdown]
# Pada Box Plot ini kita dapat melihat nilai rata-rata dari semua device adalah 1300, dan dari ketiga device tersebut tidak ada nilai outliers yang terlihat.

# %%
UNTUNG = df['Device'].value_counts().head(5).index
PENDAPATAN = df[df['Device'].isin(UNTUNG)]

plt.figure(figsize=(12, 7)) # Ukuran figure
PENDAPATAN.boxplot(column='Profit', by='Device', ax=plt.gca(), grid=False, patch_artist=True, medianprops=dict(color='red'))
plt.title('Keuntungan Setiap Device', fontsize=16) # Judul
plt.xlabel('Device', fontsize=12) # X Keterangan
plt.ylabel('Profit', fontsize=12) # Y Keterangan
plt.xticks(rotation=45, ha='right')
plt.suptitle('') # Menghilangkan judul default dari boxplot.by
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Scatterplot**

# %% [markdown]
# Pada Scatterplot terlihat banyak dapat yang tersebar secara acak namun tetap memiliki sedikit korelasi positif meski tidak banyak.
#
# - pada scatter plot anatar kolom cost dan sale amount, kita dapat melihat di bagian kiri terlihat hanya garislurus keatas, namun di bagian kanan terdapat banyak titik acak.
#
# - pada bagian profit dan sale amount, kita dapat melihat keduanya berkorelasi positif dan saling berhubungan erat.
#
# - pada bagian impression dan sale amount terlihat acak dan tersebar, namun tetap ada titik yang berada di jalur positif.
#
# - pada bagian leads dengan sale amount, terdapat titik terpisah yang unik karena mereka semua bergaris lurus dari atas kebawah namun saling terpisah.

# %%
plt.figure(figsize=(10, 6)) # Ukuran
plt.scatter(df['Cost'], df['Sale_Amount'], alpha=0.7, color='teal') # Color (Warna)
plt.title('Korelasi Antara Cost Dengan Sale Amount', fontsize=16) # Judul
plt.xlabel('Cost', fontsize=12) # X Keterangan
plt.ylabel('Sale Amount', fontsize=12) # Y Keterangan
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6)) # Ukuran
plt.scatter(df['Profit'], df['Sale_Amount'], alpha=0.7, color='teal') # Color (Warna)
plt.title('Korelasi Antara Profit Dengan Sale Amount', fontsize=16) # Judul
plt.xlabel('Profit', fontsize=12) # X Keterangan
plt.ylabel('Sale Amount', fontsize=12) # Y Keterangan
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6)) # Ukuran
plt.scatter(df['Impressions'], df['Sale_Amount'], alpha=0.7, color='teal') # Color (Warna)
plt.title('Korelasi Antara Impressions Dengan Sale Amount', fontsize=16) # Judul
plt.xlabel('Impressions', fontsize=12) # X Keterangan
plt.ylabel('Sale Amount', fontsize=12) # Y Keterangan
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6)) # Ukuran
plt.scatter(df['Leads'], df['Sale_Amount'], alpha=0.7, color='teal') # Color (Warna)
plt.title('Korelasi Antara Leads Dengan Sale Amount', fontsize=16) # Judul
plt.xlabel('Leads', fontsize=12) # X Keterangan
plt.ylabel('Sale Amount', fontsize=12) # Y Keterangan
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Heatmap**

# %% [markdown]
# Pada Heatmap ini kita apat melihat beberapa korelasi antar kolom dataset.
# - pada kolom clicks berkorelasi negatif dengan kolom conversion rate, artinya setiap nilai pada clicks bisa mengurangi hasil pada conversion rate, dan sebaliknya.
# - pada kolom conversion rate dan conversions memiliki korelasi yang positif, jika conversions semakin banyak maka conversion rate bisa ikut bertambah juga.
# - pada kolom sale amount dengan profit kita dapat melihat keua kolom berkorelasi penuh satu sama lain, hasil dari sale amount akan mempengaruhi profit dan begitu juga sebaliknya.

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    data=df[['Clicks','Impressions','Cost','Leads','Conversions','Conversion Rate','Sale_Amount','Profit']].corr(),
    annot=True,
    cmap='viridis',
    fmt='.2f'
)

plt.title('Korelasi Antar Variabel Numerik pada Dataset Iklan Google')
plt.show()

# %% [markdown]
# # **Menyimpan Dataset**

# %%
output_path = "/content/drive/MyDrive/CHECKPOINT 3 AVD.csv"
df.to_csv(output_path, index=False)
print(f"File Berhasil Disimpan.{output_path}")
# Out:
# File Berhasil Disimpan./content/drive/MyDrive/CHECKPOINT 3 AVD.csv
